# %% [markdown]
# # Decision Tree

# %%
from pyspark.ml.feature import StringIndexer, VectorAssembler
from pyspark.ml.regression import DecisionTreeRegressor
from pyspark.ml import Pipeline
from pyspark.sql import SparkSession
from pyspark.ml.feature import OneHotEncoder
from pyspark.ml.feature import StringIndexer, VectorAssembler
from pyspark.ml.regression import DecisionTreeRegressor
from pyspark.ml import Pipeline
from pyspark.ml.evaluation import RegressionEvaluator
import numpy as np
from pyspark.sql.types import DoubleType, IntegerType, LongType

# %%
# Spark Session
spark = SparkSession.builder \
    .appName("YellowTaxiTripPrediction") \
    .getOrCreate()

spark.sparkContext.setLogLevel("ERROR")
# Out:
# 25/05/19 16:14:33 WARN Utils: Your hostname, inigo-pena-HP-Victus resolves to a loopback address: 127.0.1.1; using 10.166.50.10 instead (on interface wlo1)
# 25/05/19 16:14:33 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/05/19 16:14:34 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# ## Prepare Data

# %%
df = spark.read.parquet("../data/processed.parquet")

df.printSchema()
# Out:
# root
#  |-- DOLocationID: integer (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- VendorID: integer (nullable = true)
#  |-- tpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- tpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- passenger_count: long (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- hour: integer (nullable = true)
#  |-- day_of_week: integer (nullable = true)
#  |-- extras: double (nullable = true)
#  |-- PU_Borough: string (nullable = true)
#  |-- PU_Zone: string (nullable = true)
#  |-- DO_Borough: string (nullable = true)
#  |-- DO_Zone: string (nullable = true)

# %%
# Relevant columns
selected_cols = ["trip_distance", "passenger_count", "PULocationID", "DOLocationID", 
                 "VendorID", "total_amount", "payment_type","hour", "day_of_week"]
df_model = df.select(*selected_cols)

# %%
# Train and test split
train_data, test_data = df_model.randomSplit([0.8, 0.2], seed=42)

# %%
# Cleaning data
train_data = train_data.na.drop(subset=["trip_distance", "passenger_count", "PULocationID", "DOLocationID", 
                                            "VendorID", "total_amount", "payment_type","hour", "day_of_week"
])

test_data = test_data.na.drop(subset=["trip_distance", "passenger_count", "PULocationID", "DOLocationID", 
                                        "VendorID", "total_amount", "payment_type","hour", "day_of_week"
])

# %%
amount_encoder = OneHotEncoder(
    inputCols=["PULocationID", "DOLocationID", "VendorID", "payment_type"],
    outputCols=["PULocationID_ohe", "DOLocationID_ohe", "VendorID_ohe", "payment_type_ohe"]
)

# %% [markdown]
# ## Building The Model

# %%
feature_cols = [
    "trip_distance", "passenger_count", "hour", "day_of_week",
    "PULocationID_ohe", "DOLocationID_ohe", "VendorID_ohe", "payment_type_ohe"
]

# Assemble features
amount_assembler = VectorAssembler(
    inputCols= feature_cols,
    outputCol="features"
)

total_amount_dt = DecisionTreeRegressor(labelCol="total_amount", featuresCol="features", maxDepth=5)

pipeline_total = Pipeline(stages=[amount_encoder, amount_assembler, total_amount_dt])
model_total = pipeline_total.fit(train_data)

# %%
predictions = model_total.transform(test_data)

rmse = RegressionEvaluator(labelCol="total_amount", predictionCol="prediction", metricName="rmse").evaluate(predictions)
mae = RegressionEvaluator(labelCol="total_amount", predictionCol="prediction", metricName="mae").evaluate(predictions)
r2 = RegressionEvaluator(labelCol="total_amount", predictionCol="prediction", metricName="r2").evaluate(predictions)

print(f"RMSE: {rmse}")
print(f"MAE: {mae}")
print(f"R2: {r2}")
# Out:
# [Stage 28:====================================================>   (16 + 1) / 17]
# RMSE: 11.346018981746182
# MAE: 4.76599297524254
# R2: 0.750139962903208

# %%
model_total.stages[-1].featureImportances
# Out:
# SparseVector(540, {0: 0.9152, 136: 0.0082, 142: 0.0029, 270: 0.0072, 535: 0.0026, 537: 0.0346, 538: 0.0293})

# %%
lines = model_total.stages[-1].toDebugString.split('\n')
for line in lines[:15]:
    print(line)
# Out:
# DecisionTreeRegressionModel: uid=DecisionTreeRegressor_f40687f9ce65, depth=5, numNodes=63, numFeatures=540
#   If (feature 0 <= 6.285)
#    If (feature 0 <= 2.205)
#     If (feature 0 <= 1.3250000000000002)
#      If (feature 537 in {0.0})
#       If (feature 538 in {0.0})
#        Predict: 2.485227072758029
#       Else (feature 538 not in {0.0})
#        Predict: 12.843589924503966
#      Else (feature 537 not in {0.0})
#       If (feature 136 in {0.0})
#        Predict: 16.36519229037444
#       Else (feature 136 not in {0.0})
#        Predict: 94.90811581676705
#     Else (feature 0 > 1.3250000000000002)

# %% [markdown]
# # Predicting Trip Distance

# %%
# Select just numerical columns
numerical_cols = [field.name for field in df.schema.fields if isinstance(field.dataType, (IntegerType, LongType, DoubleType))]

distance_model_df = df.select(*numerical_cols)

# %%
# Train and test split
train_data, test_data = distance_model_df.randomSplit([0.8, 0.2], seed=42)

# %%
# Cleaning data
train_data = train_data.na.drop(subset=["trip_distance", "passenger_count", "PULocationID", "DOLocationID", 
                                            "VendorID", "total_amount", "payment_type","hour", "day_of_week"
])

test_data = test_data.na.drop(subset=["trip_distance", "passenger_count", "PULocationID", "DOLocationID", 
                                        "VendorID", "total_amount", "payment_type","hour", "day_of_week"
])

# %%
distance_encoder = OneHotEncoder(
    inputCols=["PULocationID", "DOLocationID", "VendorID", "payment_type"],
    outputCols=["PULocationID_ohe", "DOLocationID_ohe", "VendorID_ohe", "payment_type_ohe"]
)

# %%
# Feature columns
feature_cols = [col for col in numerical_cols if col != "trip_distance"]

distance_assembler = VectorAssembler(
    inputCols=feature_cols,
    outputCol="features"
)

dt_distance = DecisionTreeRegressor(labelCol="trip_distance", featuresCol="features", maxDepth=10, minInstancesPerNode=50)

pipeline_distance = Pipeline(stages= [distance_assembler, dt_distance])
model_distance = pipeline_distance.fit(train_data)

# %%
predictions_dist = model_distance.transform(test_data)

rmse_dist = RegressionEvaluator(labelCol="trip_distance", predictionCol="prediction", metricName="rmse").evaluate(predictions_dist)
mae_dist = RegressionEvaluator(labelCol="trip_distance", predictionCol="prediction", metricName="mae").evaluate(predictions_dist)
r2_dist = RegressionEvaluator(labelCol="trip_distance", predictionCol="prediction", metricName="r2").evaluate(predictions_dist)

print(f"RMSE: {rmse_dist}")
print(f"MAE: {mae_dist}")
print(f"R2: {r2_dist}")
# Out:
# [Stage 57:====================================================>   (16 + 1) / 17]
# RMSE: 112.64211126079385
# MAE: 0.8963620960315555
# R2: -0.01863136516395758

# %%
tree_model_dist = model_distance.stages[-1]
print(tree_model_dist.toDebugString)
# Out:
# DecisionTreeRegressionModel: uid=DecisionTreeRegressor_4987509b8e96, depth=10, numNodes=1485, numFeatures=11
#   If (feature 5 <= 32.8)
#    If (feature 5 <= 22.2)
#     If (feature 5 <= 13.15)
#      If (feature 5 <= 9.65)
#       If (feature 10 <= 1.75)
#        If (feature 1 <= 138.5)
#         If (feature 1 <= 131.5)
#          If (feature 4 <= 3.5)
#           If (feature 5 <= 4.75)
#            If (feature 0 <= 113.5)
#             Predict: 0.8961319742489272
#            Else (feature 0 > 113.5)
#             Predict: 2.0771030993042374
#           Else (feature 5 > 4.75)
#            If (feature 5 <= 7.550000000000001)
#             Predict: 0.6875579497224945
#            Else (feature 5 > 7.550000000000001)
#             Predict: 1.075191902150991
#          Else (feature 4 > 3.5)
#           If (feature 0 <= 250.5)
#            If (feature 0 <= 113.5)
#             Predict: 1.6004107505070997
#            Else (feature 0 > 113.5)
#             Predict: 2.461791723510687
#           Else (feature 0 > 250.5)
#            If (feature 0 <= 262.5)
#             Predict: 4.062058823529412
#            Else (feature 0 > 262.5)
#             Predict: 6.832500000000002
#         Else (feature 1 > 131.5)
#          If (feature 0 <= 229.5)
#           If (feature 0 <= 113.5)
#            If (feature 1 <= 135.0)
#             Predict: 13.081058951965058
#            Else (feature 1 > 135.0)
#             Predict: 7.0464150943396175
#           Else (feature 0 > 113.5)
#            If (feature 0 <= 139.5)
#             Predict: 2.5858100979653305
#            Else (feature 0 > 139.5)
#             Predict: 10.81207815275311
#          Else (feature 0 > 229.5)
#           If (feature 1 <= 135.0)
#            If (feature 0 <= 262.5)
#             Predict: 18.365625
#            Else (feature 0 > 262.5)
#             Predict: 22.72965116279069
#           Else (feature 1 > 135.0)
#            If (feature 0 <= 250.5)
#             Predict: 7.263401360544218
#            Else (feature 0 > 250.5)
#             Predict: 11.242241379310345
#        Else (feature 1 > 138.5)
#         If (feature 0 <= 139.5)
#          If (feature 0 <= 113.5)
#           If (feature 5 <= 4.75)
#            If (feature 0 <= 33.5)
#             Predict: 5.354263392857144
#            Else (feature 0 > 33.5)
#             Predict: 2.2714501510574014
#           Else (feature 5 > 4.75)
#            If (feature 5 <= 7.550000000000001)
#             Predict: 0.7289561855670104
#            Else (feature 5 > 7.550000000000001)
#             Predict: 1.1111320754716978
#          Else (feature 0 > 113.5)
#           If (feature 5 <= 4.75)
#            If (feature 8 <= 17.5)
#             Predict: 7.681267123287673
#            Else (feature 8 > 17.5)
#             Predict: 4.1427999999999985
#           Else (feature 5 > 4.75)
#            If (feature 5 <= 7.550000000000001)
#             Predict: 0.7342592592592594
#            Else (feature 5 > 7.550000000000001)
#             Predict: 1.1825925925925926
#         Else (feature 0 > 139.5)
#          If (feature 6 <= 7.415)
#           If (feature 4 <= 3.5)
#            If (feature 8 <= 15.5)
#             Predict: 0.7667894797821803
#            Else (feature 8 > 15.5)
#             Predict: 1.1782176069435835
#           Else (feature 4 > 3.5)
#            If (feature 0 <= 250.5)
#             Predict: 1.366262561195568
#            Else (feature 0 > 250.5)
#             Predict: 2.416377551020408
#          Else (feature 6 > 7.415)
#           Predict: 6.292428571428588
#       Else (feature 10 > 1.75)
#        If (feature 5 <= 6.75)
#         If (feature 5 <= 5.449999999999999)
#          If (feature 5 <= 4.75)
#           If (feature 10 <= 12.22)
#            If (feature 6 <= 0.060000000000000005)
#             Predict: 0.25064559847224854
#            Else (feature 6 > 0.060000000000000005)
#             Predict: 0.33427244433804126
#           Else (feature 10 > 12.22)
#            If (feature 0 <= 167.0)
#             Predict: 0.7494505494505493
#            Else (feature 0 > 167.0)
#             Predict: 4.249599999999999
#          Else (feature 5 > 4.75)
#           If (feature 8 <= 7.5)
#            If (feature 8 <= 3.5)
#             Predict: 0.5038766388557807
#            Else (feature 8 > 3.5)
#             Predict: 0.538972953216374
#           Else (feature 8 > 7.5)
#            If (feature 6 <= 0.060000000000000005)
#             Predict: 0.4479591620821026
#            Else (feature 6 > 0.060000000000000005)
#             Predict: 0.4809922344035507
#         Else (feature 5 > 5.449999999999999)
#          If (feature 5 <= 6.15)
#           If (feature 8 <= 7.5)
#            If (feature 8 <= 3.5)
#             Predict: 0.6340348360655738
#            Else (feature 8 > 3.5)
#             Predict: 0.66897939853185
#           Else (feature 8 > 7.5)
#            If (feature 8 <= 19.5)
#             Predict: 0.5756270620082898
#            Else (feature 8 > 19.5)
#             Predict: 0.624914783117548
#          Else (feature 5 > 6.15)
#           If (feature 8 <= 7.5)
#            If (feature 3 <= 1.5)
#             Predict: 0.7915045025258071
#            Else (feature 3 > 1.5)
#             Predict: 0.7518446139180172
#           Else (feature 8 > 7.5)
#            If (feature 8 <= 19.5)
#             Predict: 0.681314692745778
#            Else (feature 8 > 19.5)
#             Predict: 0.7420962414578587
#        Else (feature 5 > 6.75)
#         If (feature 5 <= 8.25)
#          If (feature 5 <= 7.550000000000001)
#           If (feature 8 <= 7.5)
#            If (feature 1 <= 235.5)
#             Predict: 0.8986277298120874
#            Else (feature 1 > 235.5)
#             Predict: 0.9478334648776643
#           Else (feature 8 > 7.5)
#            If (feature 8 <= 19.5)
#             Predict: 0.7857920040485833
#            Else (feature 8 > 19.5)
#             Predict: 0.865662511309943
#          Else (feature 5 > 7.550000000000001)
#           If (feature 8 <= 7.5)
#            If (feature 1 <= 235.5)
#             Predict: 1.0332665759284463
#            Else (feature 1 > 235.5)
#             Predict: 1.0893255020841226
#           Else (feature 8 > 7.5)
#            If (feature 8 <= 19.5)
#             Predict: 0.8892237294827688
#            Else (feature 8 > 19.5)
#             Predict: 0.9867144252686422
#         Else (feature 5 > 8.25)
#          If (feature 5 <= 8.95)
#           If (feature 8 <= 7.5)
#            If (feature 8 <= 6.5)
#             Predict: 1.1911374948154296
#            Else (feature 8 > 6.5)
#             Predict: 1.1337349024465762
#           Else (feature 8 > 7.5)
#            If (feature 8 <= 19.5)
#             Predict: 0.9939059940586914
#            Else (feature 8 > 19.5)
#             Predict: 1.1107395133466496
#          Else (feature 5 > 8.95)
#           If (feature 8 <= 7.5)
#            If (feature 8 <= 6.5)
#             Predict: 1.3356778679026649
#            Else (feature 8 > 6.5)
#             Predict: 1.265097213220998
#           Else (feature 8 > 7.5)
#            If (feature 8 <= 19.5)
#             Predict: 1.0988856721320601
#            Else (feature 8 > 19.5)
#             Predict: 1.231670662745986
#      Else (feature 5 > 9.65)
#       If (feature 5 <= 11.05)
#        If (feature 8 <= 7.5)
#         If (feature 5 <= 10.35)
#          If (feature 10 <= 3.875)
#           If (feature 8 <= 4.5)
#            If (feature 8 <= 1.5)
#             Predict: 1.1361797752808989
#            Else (feature 8 > 1.5)
#             Predict: 0.5715714285714284
#           Else (feature 8 > 4.5)
#            If (feature 4 <= 1.5)
#             Predict: 1.221339285714286
#            Else (feature 4 > 1.5)
#             Predict: 1.4458620689655175
#          Else (feature 10 > 3.875)
#           If (feature 8 <= 6.5)
#            If (feature 8 <= 2.5)
#             Predict: 1.4385377358490565
#            Else (feature 8 > 2.5)
#             Predict: 1.5471287465940051
#           Else (feature 8 > 6.5)
#            If (feature 9 <= 1.5)
#             Predict: 1.650196078431373
#            Else (feature 9 > 1.5)
#             Predict: 1.3858105403602394
#         Else (feature 5 > 10.35)
#          If (feature 8 <= 6.5)
#           If (feature 8 <= 2.5)
#            If (feature 0 <= 161.5)
#             Predict: 1.5361459993624487
#            Else (feature 0 > 161.5)
#             Predict: 1.629561904761904
#           Else (feature 8 > 2.5)
#            If (feature 1 <= 233.5)
#             Predict: 1.6781390793339865
#            Else (feature 1 > 233.5)
#             Predict: 1.7933333333333341
#          Else (feature 8 > 6.5)
#           If (feature 1 <= 230.5)
#            If (feature 9 <= 1.5)
#             Predict: 1.8077272727272726
#            Else (feature 9 > 1.5)
#             Predict: 1.474288901282766
#           Else (feature 1 > 230.5)
#            If (feature 0 <= 234.5)
#             Predict: 1.6775120192307693
#            Else (feature 0 > 234.5)
#             Predict: 1.4612500000000004
#        Else (feature 8 > 7.5)
#         If (feature 8 <= 19.5)
#          If (feature 9 <= 1.5)
#           If (feature 8 <= 10.5)
#            If (feature 5 <= 10.35)
#             Predict: 1.5280903790087452
#            Else (feature 5 > 10.35)
#             Predict: 1.685218150087259
#           Else (feature 8 > 10.5)
#            If (feature 5 <= 10.35)
#             Predict: 1.3191479495725267
#            Else (feature 5 > 10.35)
#             Predict: 1.4354750304506727
#          Else (feature 9 > 1.5)
#           If (feature 5 <= 10.35)
#            If (feature 0 <= 237.5)
#             Predict: 1.1640289210642363
#            Else (feature 0 > 237.5)
#             Predict: 1.303358551123337
#           Else (feature 5 > 10.35)
#            If (feature 0 <= 237.5)
#             Predict: 1.2673716996228142
#            Else (feature 0 > 237.5)
#             Predict: 1.4227623438068648
#         Else (feature 8 > 19.5)
#          If (feature 0 <= 234.5)
#           If (feature 9 <= 5.5)
#            If (feature 5 <= 10.35)
#             Predict: 1.3678509951586872
#            Else (feature 5 > 10.35)
#             Predict: 1.501787412055522
#           Else (feature 9 > 5.5)
#            If (feature 5 <= 10.35)
#             Predict: 1.2318178396687982
#            Else (feature 5 > 10.35)
#             Predict: 1.3296126228269094
#          Else (feature 0 > 234.5)
#           If (feature 5 <= 10.35)
#            If (feature 0 <= 236.5)
#             Predict: 1.5752046169989502
#            Else (feature 0 > 236.5)
#             Predict: 1.4599829642248725
#           Else (feature 5 > 10.35)
#            If (feature 0 <= 236.5)
#             Predict: 1.7481555333998
#            Else (feature 0 > 236.5)
#             Predict: 1.5948012310848934
#       Else (feature 5 > 11.05)
#        If (feature 8 <= 7.5)
#         If (feature 5 <= 12.05)
#          If (feature 5 <= 11.45)
#           If (feature 8 <= 6.5)
#            If (feature 8 <= 2.5)
#             Predict: 1.7272660550458707
#            Else (feature 8 > 2.5)
#             Predict: 1.864003261312679
#           Else (feature 8 > 6.5)
#            If (feature 1 <= 230.5)
#             Predict: 1.61653488372093
#            Else (feature 1 > 230.5)
#             Predict: 1.751299093655589
#          Else (feature 5 > 11.45)
#           Predict: 0.3736111111111313
#         Else (feature 5 > 12.05)
#          If (feature 5 <= 12.45)
#           If (feature 8 <= 6.5)
#            If (feature 8 <= 2.5)
#             Predict: 1.875106214016279
#            Else (feature 8 > 2.5)
#             Predict: 2.0462782294489625
#           Else (feature 8 > 6.5)
#            If (feature 9 <= 1.5)
#             Predict: 2.1695454545454544
#            Else (feature 9 > 1.5)
#             Predict: 1.782548359966358
#          Else (feature 5 > 12.45)
#           If (feature 10 <= 3.875)
#            If (feature 8 <= 3.5)
#             Predict: 1.1819642857142856
#            Else (feature 8 > 3.5)
#             Predict: 1.872095238095238
#           Else (feature 10 > 3.875)
#            If (feature 8 <= 6.5)
#             Predict: 2.0956896014943966
#            Else (feature 8 > 6.5)
#             Predict: 1.9368658047258143
#        Else (feature 8 > 7.5)
#         If (feature 8 <= 19.5)
#          If (feature 5 <= 12.05)
#           If (feature 9 <= 1.5)
#            If (feature 8 <= 11.5)
#             Predict: 1.7607798960138643
#            Else (feature 8 > 11.5)
#             Predict: 1.5302249229094869
#           Else (feature 9 > 1.5)
#            If (feature 0 <= 237.5)
#             Predict: 1.3690055503236014
#            Else (feature 0 > 237.5)
#             Predict: 1.537989499295683
#          Else (feature 5 > 12.05)
#           If (feature 9 <= 2.5)
#            If (feature 9 <= 1.5)
#             Predict: 1.7759393748026502
#            Else (feature 9 > 1.5)
#             Predict: 1.6462483560600794
#           Else (feature 9 > 2.5)
#            If (feature 0 <= 237.5)
#             Predict: 1.506044409460815
#            Else (feature 0 > 237.5)
#             Predict: 1.6966548919740376
#         Else (feature 8 > 19.5)
#          If (feature 5 <= 12.05)
#           If (feature 0 <= 234.5)
#            If (feature 9 <= 5.5)
#             Predict: 1.6331703485517923
#            Else (feature 9 > 5.5)
#             Predict: 1.4537204258675065
#           Else (feature 0 > 234.5)
#            If (feature 0 <= 236.5)
#             Predict: 1.8690419161676648
#            Else (feature 0 > 236.5)
#             Predict: 1.728269841269841
#          Else (feature 5 > 12.05)
#           If (feature 9 <= 5.5)
#            If (feature 0 <= 234.5)
#             Predict: 1.8426280474166847
#            Else (feature 0 > 234.5)
#             Predict: 1.9996144539441858
#           Else (feature 9 > 5.5)
#            If (feature 0 <= 234.5)
#             Predict: 1.6231732215774768
#            Else (feature 0 > 234.5)
#             Predict: 1.9013526011560695
#     Else (feature 5 > 13.15)
#      If (feature 5 <= 17.6)
#       If (feature 5 <= 15.25)
#        If (feature 8 <= 7.5)
#         If (feature 5 <= 14.95)
#          If (feature 5 <= 14.55)
#           If (feature 8 <= 6.5)
#            If (feature 8 <= 2.5)
#             Predict: 2.253684416601409
#            Else (feature 8 > 2.5)
#             Predict: 2.4654755222949807
#           Else (feature 8 > 6.5)
#            If (feature 1 <= 237.5)
#             Predict: 2.0722658920027346
#            Else (feature 1 > 237.5)
#             Predict: 2.2920497512437823
#          Else (feature 5 > 14.55)
#           If (feature 8 <= 6.5)
#            If (feature 8 <= 2.5)
#             Predict: 2.533272613065327
#            Else (feature 8 > 2.5)
#             Predict: 2.710989884393064
#           Else (feature 8 > 6.5)
#            If (feature 1 <= 192.0)
#             Predict: 2.2735406698564598
#            Else (feature 1 > 192.0)
#             Predict: 2.4640766073871405
#         Else (feature 5 > 14.95)
#          Predict: 0.1380645161289947
#        Else (feature 8 > 7.5)
#         If (feature 8 <= 19.5)
#          If (feature 9 <= 2.5)
#           If (feature 5 <= 14.55)
#            If (feature 9 <= 1.5)
#             Predict: 2.0169952741020793
#            Else (feature 9 > 1.5)
#             Predict: 1.8699753350324768
#           Else (feature 5 > 14.55)
#            If (feature 9 <= 1.5)
#             Predict: 2.198933215781358
#            Else (feature 9 > 1.5)
#             Predict: 2.0565751056473314
#          Else (feature 9 > 2.5)
#           If (feature 0 <= 237.5)
#            If (feature 1 <= 237.5)
#             Predict: 1.7223732631926596
#            Else (feature 1 > 237.5)
#             Predict: 1.950259448110376
#           Else (feature 0 > 237.5)
#            If (feature 5 <= 13.85)
#             Predict: 1.8686120550885363
#            Else (feature 5 > 13.85)
#             Predict: 2.0302218395461917
#         Else (feature 8 > 19.5)
#          If (feature 9 <= 5.5)
#           If (feature 5 <= 14.55)
#            If (feature 0 <= 234.5)
#             Predict: 2.129601493550577
#            Else (feature 0 > 234.5)
#             Predict: 2.279001685708933
#           Else (feature 5 > 14.55)
#            If (feature 8 <= 21.5)
#             Predict: 2.3299682658204217
#            Else (feature 8 > 21.5)
#             Predict: 2.485958612294583
#          Else (feature 9 > 5.5)
#           If (feature 0 <= 234.5)
#            If (feature 5 <= 14.55)
#             Predict: 1.8669923968590305
#            Else (feature 5 > 14.55)
#             Predict: 2.0486516853932617
#           Else (feature 0 > 234.5)
#            If (feature 0 <= 238.5)
#             Predict: 2.3203468697123526
#            Else (feature 0 > 238.5)
#             Predict: 2.12349459598559
#       Else (feature 5 > 15.25)
#        If (feature 8 <= 7.5)
#         If (feature 10 <= 1.75)
#          If (feature 2 <= 1.5)
#           If (feature 7 <= 17.18)
#            Predict: 0.688888888888889
#           Else (feature 7 > 17.18)
#            If (feature 8 <= 5.5)
#             Predict: 1.0255813953488373
#            Else (feature 8 > 5.5)
#             Predict: 1.3274509803921566
#          Else (feature 2 > 1.5)
#           If (feature 6 <= 0.76)
#            Predict: 2.4978181818181824
#           Else (feature 6 > 0.76)
#            Predict: 2.1098039215686284
#         Else (feature 10 > 1.75)
#          If (feature 8 <= 6.5)
#           If (feature 5 <= 15.95)
#            If (feature 8 <= 2.5)
#             Predict: 2.7021047227926074
#            Else (feature 8 > 2.5)
#             Predict: 2.870294612794612
#           Else (feature 5 > 15.95)
#            If (feature 10 <= 3.875)
#             Predict: 2.22858064516129
#            Else (feature 10 > 3.875)
#             Predict: 3.007507418397625
#          Else (feature 8 > 6.5)
#           If (feature 9 <= 1.5)
#            If (feature 0 <= 139.5)
#             Predict: 3.3003846153846155
#            Else (feature 0 > 139.5)
#             Predict: 3.178571428571428
#           Else (feature 9 > 1.5)
#            If (feature 9 <= 6.5)
#             Predict: 2.5623931375399827
#            Else (feature 9 > 6.5)
#             Predict: 3.133417721518987
#        Else (feature 8 > 7.5)
#         If (feature 8 <= 19.5)
#          If (feature 7 <= 18.39)
#           If (feature 4 <= 1.5)
#            If (feature 2 <= 1.5)
#             Predict: 0.8908812260536397
#            Else (feature 2 > 1.5)
#             Predict: 1.9183928571428583
#           Else (feature 4 > 1.5)
#            If (feature 0 <= 78.5)
#             Predict: 2.161034482758621
#            Else (feature 0 > 78.5)
#             Predict: 2.4890419161676642
#          Else (feature 7 > 18.39)
#           If (feature 9 <= 2.5)
#            If (feature 9 <= 1.5)
#             Predict: 2.470194290976058
#            Else (feature 9 > 1.5)
#             Predict: 2.278306451612904
#           Else (feature 9 > 2.5)
#            If (feature 0 <= 237.5)
#             Predict: 2.065656214490558
#            Else (feature 0 > 237.5)
#             Predict: 2.2829976370895446
#         Else (feature 8 > 19.5)
#          If (feature 9 <= 5.5)
#           If (feature 5 <= 15.95)
#            If (feature 9 <= 3.5)
#             Predict: 2.639377845220029
#            Else (feature 9 > 3.5)
#             Predict: 2.4755607895917433
#           Else (feature 5 > 15.95)
#            If (feature 9 <= 3.5)
#             Predict: 2.879027303754264
#            Else (feature 9 > 3.5)
#             Predict: 2.6840246324990082
#          Else (feature 9 > 5.5)
#           If (feature 0 <= 234.5)
#            If (feature 5 <= 15.95)
#             Predict: 2.1678072135333526
#            Else (feature 5 > 15.95)
#             Predict: 2.4025714786879524
#           Else (feature 0 > 234.5)
#            If (feature 0 <= 250.5)
#             Predict: 2.544369482976041
#            Else (feature 0 > 250.5)
#             Predict: 2.7716111111111115
#      Else (feature 5 > 17.6)
#       If (feature 5 <= 19.9)
#        If (feature 8 <= 7.5)
#         If (feature 10 <= 1.75)
#          If (feature 8 <= 5.5)
#           Predict: 1.2505050505050506
#          Else (feature 8 > 5.5)
#           If (feature 2 <= 1.5)
#            If (feature 7 <= 20.18)
#             Predict: 1.9550335570469795
#            Else (feature 7 > 20.18)
#             Predict: 2.492753623188404
#           Else (feature 2 > 1.5)
#            Predict: 3.1870270270270273
#         Else (feature 10 > 1.75)
#          If (feature 5 <= 18.45)
#           If (feature 8 <= 6.5)
#            If (feature 8 <= 1.5)
#             Predict: 3.27564871481028
#            Else (feature 8 > 1.5)
#             Predict: 3.460429864253393
#           Else (feature 8 > 6.5)
#            If (feature 9 <= 1.5)
#             Predict: 3.694411764705883
#            Else (feature 9 > 1.5)
#             Predict: 2.950274626865672
#          Else (feature 5 > 18.45)
#           If (feature 8 <= 6.5)
#            If (feature 8 <= 1.5)
#             Predict: 3.6136459802538767
#            Else (feature 8 > 1.5)
#             Predict: 3.7881754221388375
#           Else (feature 8 > 6.5)
#            If (feature 0 <= 139.5)
#             Predict: 3.5760613810741693
#            Else (feature 0 > 139.5)
#             Predict: 3.204414019715223
#        Else (feature 8 > 7.5)
#         If (feature 8 <= 19.5)
#          If (feature 9 <= 2.5)
#           If (feature 5 <= 18.45)
#            If (feature 9 <= 1.5)
#             Predict: 2.8365511079342376
#            Else (feature 9 > 1.5)
#             Predict: 2.611003612376309
#           Else (feature 5 > 18.45)
#            If (feature 7 <= 20.18)
#             Predict: 1.9312820512820514
#            Else (feature 7 > 20.18)
#             Predict: 2.977826978269782
#          Else (feature 9 > 2.5)
#           If (feature 5 <= 18.45)
#            If (feature 0 <= 47.5)
#             Predict: 2.8107214611872156
#            Else (feature 0 > 47.5)
#             Predict: 2.366824833912572
#           Else (feature 5 > 18.45)
#            If (feature 0 <= 33.5)
#             Predict: 3.2145151811949084
#            Else (feature 0 > 33.5)
#             Predict: 2.599154902446407
#         Else (feature 8 > 19.5)
#          If (feature 9 <= 5.5)
#           If (feature 5 <= 18.45)
#            If (feature 8 <= 21.5)
#             Predict: 2.99410479704797
#            Else (feature 8 > 21.5)
#             Predict: 3.217752066115701
#           Else (feature 5 > 18.45)
#            If (feature 9 <= 3.5)
#             Predict: 3.525286640079763
#            Else (feature 9 > 3.5)
#             Predict: 3.2809581413210442
#          Else (feature 9 > 5.5)
#           If (feature 5 <= 18.45)
#            If (feature 0 <= 234.5)
#             Predict: 2.673637162310565
#            Else (feature 0 > 234.5)
#             Predict: 2.979441624365483
#           Else (feature 5 > 18.45)
#            If (feature 8 <= 22.5)
#             Predict: 2.9466312056737585
#            Else (feature 8 > 22.5)
#             Predict: 3.1920765472312693
#       Else (feature 5 > 19.9)
#        If (feature 10 <= 4.125)
#         If (feature 9 <= 2.5)
#          If (feature 8 <= 4.5)
#           Predict: 1.6937777777777778
#          Else (feature 8 > 4.5)
#           If (feature 9 <= 1.5)
#            If (feature 8 <= 11.5)
#             Predict: 3.8702634467618
#            Else (feature 8 > 11.5)
#             Predict: 3.34064477965099
#           Else (feature 9 > 1.5)
#            If (feature 8 <= 7.5)
#             Predict: 3.7033590733590738
#            Else (feature 8 > 7.5)
#             Predict: 3.1380842230130472
#         Else (feature 9 > 2.5)
#          If (feature 8 <= 8.5)
#           If (feature 8 <= 4.5)
#            If (feature 7 <= 24.625)
#             Predict: 2.4402020202020203
#            Else (feature 7 > 24.625)
#             Predict: 0.9176388888888892
#           Else (feature 8 > 4.5)
#            If (feature 8 <= 7.5)
#             Predict: 3.649076923076923
#            Else (feature 8 > 7.5)
#             Predict: 3.1092277115275393
#          Else (feature 8 > 8.5)
#           If (feature 9 <= 5.5)
#            If (feature 0 <= 139.5)
#             Predict: 2.973037865748709
#            Else (feature 0 > 139.5)
#             Predict: 2.612466253595928
#           Else (feature 9 > 5.5)
#            If (feature 8 <= 13.5)
#             Predict: 3.1528440820360766
#            Else (feature 8 > 13.5)
#             Predict: 2.919154375614553
#        Else (feature 10 > 4.125)
#         If (feature 1 <= 248.0)
#          If (feature 8 <= 6.5)
#           If (feature 10 <= 4.375)
#            Predict: 4.951139240506328
#           Else (feature 10 > 4.375)
#            If (feature 8 <= 1.5)
#             Predict: 4.007275803722507
#            Else (feature 8 > 1.5)
#             Predict: 4.202222222222223
#          Else (feature 8 > 6.5)
#           If (feature 8 <= 18.5)
#            If (feature 1 <= 160.0)
#             Predict: 3.226505919003115
#            Else (feature 1 > 160.0)
#             Predict: 2.8952560932532676
#           Else (feature 8 > 18.5)
#            If (feature 9 <= 3.5)
#             Predict: 3.8717195456325877
#            Else (feature 9 > 3.5)
#             Predict: 3.4837586460632846
#         Else (feature 1 > 248.0)
#          If (feature 7 <= 33.61)
#           If (feature 8 <= 7.5)
#            If (feature 0 <= 234.5)
#             Predict: 4.019639830508474
#            Else (feature 0 > 234.5)
#             Predict: 4.240600858369098
#           Else (feature 8 > 7.5)
#            If (feature 8 <= 20.5)
#             Predict: 3.3343178807947025
#            Else (feature 8 > 20.5)
#             Predict: 3.72015984015984
#          Else (feature 7 > 33.61)
#           If (feature 3 <= 1.5)
#            If (feature 10 <= 6.625)
#             Predict: 3.3654605263157897
#            Else (feature 10 > 6.625)
#             Predict: 4.189583333333334
#           Else (feature 3 > 1.5)
#            Predict: 44.150000000000006
#    Else (feature 5 > 22.2)
#     If (feature 10 <= 1.75)
#      If (feature 7 <= 33.61)
#       If (feature 7 <= 24.625)
#        If (feature 9 <= 5.5)
#         If (feature 4 <= 1.5)
#          If (feature 8 <= 16.5)
#           If (feature 1 <= 169.0)
#            If (feature 8 <= 8.5)
#             Predict: 3.939830508474575
#            Else (feature 8 > 8.5)
#             Predict: 3.6535294117647057
#           Else (feature 1 > 169.0)
#            If (feature 0 <= 106.5)
#             Predict: 3.7729729729729726
#            Else (feature 0 > 106.5)
#             Predict: 3.0825609756097565
#          Else (feature 8 > 16.5)
#           Predict: 2.944117647058821
#         Else (feature 4 > 1.5)
#          If (feature 8 <= 11.5)
#           Predict: 1.5796153846153846
#          Else (feature 8 > 11.5)
#           Predict: 0.6593749999999998
#        Else (feature 9 > 5.5)
#         If (feature 1 <= 68.5)
#          Predict: 606.3938983050847
#         Else (feature 1 > 68.5)
#          If (feature 9 <= 6.5)
#           If (feature 1 <= 151.5)
#            Predict: 3.3862
#           Else (feature 1 > 151.5)
#            Predict: 3.0696428571428576
#          Else (feature 9 > 6.5)
#           Predict: 1.9910526315789476
#       Else (feature 7 > 24.625)
#        If (feature 0 <= 262.5)
#         If (feature 5 <= 27.85)
#          If (feature 6 <= 0.060000000000000005)
#           If (feature 7 <= 27.275)
#            If (feature 7 <= 25.755000000000003)
#             Predict: 3.9571856287425153
#            Else (feature 7 > 25.755000000000003)
#             Predict: 4.633536067892504
#           Else (feature 7 > 27.275)
#            If (feature 7 <= 28.915)
#             Predict: 5.14429882044561
#            Else (feature 7 > 28.915)
#             Predict: 5.6801399688958005
#          Else (feature 6 > 0.060000000000000005)
#           If (feature 0 <= 238.5)
#            If (feature 0 <= 113.5)
#             Predict: 1.8991452991452993
#            Else (feature 0 > 113.5)
#             Predict: 2.790059880239521
#           Else (feature 0 > 238.5)
#            If (feature 1 <= 151.5)
#             Predict: 4.5148
#            Else (feature 1 > 151.5)
#             Predict: 3.586166666666666
#         Else (feature 5 > 27.85)
#          If (feature 8 <= 18.5)
#           If (feature 8 <= 4.5)
#            Predict: 2.9723333333333333
#           Else (feature 8 > 4.5)
#            If (feature 7 <= 31.025)
#             Predict: 6.023631100082711
#            Else (feature 7 > 31.025)
#             Predict: 6.901138819617624
#          Else (feature 8 > 18.5)
#           Predict: 3.265799999999999
#        Else (feature 0 > 262.5)
#         If (feature 1 <= 229.5)
#          Predict: 196.16555555555556
#         Else (feature 1 > 229.5)
#          Predict: 3.0344642857142907
#      Else (feature 7 > 33.61)
#       If (feature 8 <= 7.5)
#        If (feature 0 <= 195.5)
#         If (feature 0 <= 78.5)
#          Predict: 6.678813559322035
#         Else (feature 0 > 78.5)
#          Predict: 5.1726027397260275
#        Else (feature 0 > 195.5)
#         Predict: 755.398787878788
#       Else (feature 8 > 7.5)
#        If (feature 0 <= 250.5)
#         If (feature 6 <= 0.005)
#          If (feature 8 <= 16.5)
#           If (feature 9 <= 2.5)
#            Predict: 7.072987012987013
#           Else (feature 9 > 2.5)
#            If (feature 0 <= 53.5)
#             Predict: 7.166153846153845
#            Else (feature 0 > 53.5)
#             Predict: 8.061860465116279
#          Else (feature 8 > 16.5)
#           Predict: 4.942096774193546
#         Else (feature 6 > 0.005)
#          If (feature 8 <= 15.5)
#           If (feature 7 <= 37.75)
#            Predict: 4.303829787234042
#           Else (feature 7 > 37.75)
#            Predict: 5.80346153846154
#          Else (feature 8 > 15.5)
#           Predict: 2.690655737704918
#        Else (feature 0 > 250.5)
#         Predict: 120.68169491525423
#     Else (feature 10 > 1.75)
#      If (feature 10 <= 8.215)
#       If (feature 5 <= 27.85)
#        If (feature 5 <= 24.25)
#         If (feature 8 <= 7.5)
#          If (feature 7 <= 25.755000000000003)
#           Predict: 1.024871794871795
#          Else (feature 7 > 25.755000000000003)
#           If (feature 10 <= 4.125)
#            If (feature 8 <= 4.5)
#             Predict: 2.729381443298969
#            Else (feature 8 > 4.5)
#             Predict: 4.333026052104208
#           Else (feature 10 > 4.125)
#            If (feature 10 <= 4.375)
#             Predict: 5.438085106382978
#            Else (feature 10 > 4.375)
#             Predict: 4.567084715770852
#         Else (feature 8 > 7.5)
#          If (feature 8 <= 19.5)
#           If (feature 9 <= 2.5)
#            If (feature 9 <= 1.5)
#             Predict: 3.9620229320229337
#            Else (feature 9 > 1.5)
#             Predict: 3.6702114649681534
#           Else (feature 9 > 2.5)
#            If (feature 0 <= 139.5)
#             Predict: 3.551828439838803
#            Else (feature 0 > 139.5)
#             Predict: 3.2228340425531914
#          Else (feature 8 > 19.5)
#           If (feature 9 <= 3.5)
#            If (feature 10 <= 3.875)
#             Predict: 3.2474418604651154
#            Else (feature 10 > 3.875)
#             Predict: 4.462384566729917
#           Else (feature 9 > 3.5)
#            If (feature 7 <= 25.755000000000003)
#             Predict: 1.4588679245283018
#            Else (feature 7 > 25.755000000000003)
#             Predict: 4.002052872062659
#        Else (feature 5 > 24.25)
#         If (feature 8 <= 7.5)
#          If (feature 10 <= 4.125)
#           If (feature 8 <= 4.5)
#            If (feature 1 <= 135.0)
#             Predict: 3.9631168831168835
#            Else (feature 1 > 135.0)
#             Predict: 2.4075362318840563
#           Else (feature 8 > 4.5)
#            If (feature 8 <= 6.5)
#             Predict: 5.486723549488054
#            Else (feature 8 > 6.5)
#             Predict: 4.872191011235956
#          Else (feature 10 > 4.125)
#           If (feature 10 <= 4.375)
#            If (feature 7 <= 31.025)
#             Predict: 6.045074626865671
#            Else (feature 7 > 31.025)
#             Predict: 6.237011494252872
#           Else (feature 10 > 4.375)
#            If (feature 7 <= 37.75)
#             Predict: 5.177317073170735
#            Else (feature 7 > 37.75)
#             Predict: 5.426200156372169
#         Else (feature 8 > 7.5)
#          If (feature 8 <= 18.5)
#           If (feature 9 <= 2.5)
#            If (feature 10 <= 3.875)
#             Predict: 5.701019417475727
#            Else (feature 10 > 3.875)
#             Predict: 4.377684698986443
#           Else (feature 9 > 2.5)
#            If (feature 0 <= 89.5)
#             Predict: 4.2987653252560225
#            Else (feature 0 > 89.5)
#             Predict: 3.799715827641454
#          Else (feature 8 > 18.5)
#           If (feature 9 <= 5.5)
#            If (feature 9 <= 3.5)
#             Predict: 5.0671394705649915
#            Else (feature 9 > 3.5)
#             Predict: 4.724813284132849
#           Else (feature 9 > 5.5)
#            If (feature 10 <= 4.125)
#             Predict: 3.9339946737683076
#            Else (feature 10 > 4.125)
#             Predict: 4.453972377507407
#       Else (feature 5 > 27.85)
#        If (feature 8 <= 7.5)
#         If (feature 7 <= 44.535)
#          If (feature 0 <= 139.5)
#           If (feature 1 <= 115.0)
#            If (feature 10 <= 4.125)
#             Predict: 5.363153153153154
#            Else (feature 10 > 4.125)
#             Predict: 6.172492877492878
#           Else (feature 1 > 115.0)
#            If (feature 1 <= 135.0)
#             Predict: 7.21712365591398
#            Else (feature 1 > 135.0)
#             Predict: 6.362274183215886
#          Else (feature 0 > 139.5)
#           If (feature 10 <= 3.875)
#            If (feature 1 <= 135.0)
#             Predict: 6.510138888888889
#            Else (feature 1 > 135.0)
#             Predict: 3.3770175438596515
#           Else (feature 10 > 3.875)
#            If (feature 8 <= 6.5)
#             Predict: 6.253196920583469
#            Else (feature 8 > 6.5)
#             Predict: 5.860662525879922
#         Else (feature 7 > 44.535)
#          If (feature 8 <= 5.5)
#           If (feature 6 <= 10.01)
#            If (feature 3 <= 1.5)
#             Predict: 6.856311475409837
#            Else (feature 3 > 1.5)
#             Predict: 6.538518518518523
#           Else (feature 6 > 10.01)
#            If (feature 1 <= 151.5)
#             Predict: 6.2050877192982465
#            Else (feature 1 > 151.5)
#             Predict: 6.5627999999999975
#          Else (feature 8 > 5.5)
#           Predict: 7.1715625
#        Else (feature 8 > 7.5)
#         If (feature 8 <= 18.5)
#          If (feature 0 <= 139.5)
#           If (feature 10 <= 3.875)
#            If (feature 4 <= 1.5)
#             Predict: 6.209880478087649
#            Else (feature 4 > 1.5)
#             Predict: 6.954297188755022
#           Else (feature 10 > 3.875)
#            If (feature 0 <= 33.5)
#             Predict: 5.693682783551737
#            Else (feature 0 > 33.5)
#             Predict: 5.158732442617336
#          Else (feature 0 > 139.5)
#           If (feature 9 <= 2.5)
#            If (feature 9 <= 1.5)
#             Predict: 5.511085743277524
#            Else (feature 9 > 1.5)
#             Predict: 5.044868965517239
#           Else (feature 9 > 2.5)
#            If (feature 9 <= 5.5)
#             Predict: 4.522997432605905
#            Else (feature 9 > 5.5)
#             Predict: 5.024939892731642
#         Else (feature 8 > 18.5)
#          If (feature 9 <= 4.5)
#           If (feature 8 <= 20.5)
#            If (feature 9 <= 2.5)
#             Predict: 6.105795246800732
#            Else (feature 9 > 2.5)
#             Predict: 5.79412327947337
#           Else (feature 8 > 20.5)
#            If (feature 10 <= 4.375)
#             Predict: 6.914419354838709
#            Else (feature 10 > 4.375)
#             Predict: 6.161834285714285
#          Else (feature 9 > 4.5)
#           If (feature 9 <= 6.5)
#            If (feature 10 <= 4.375)
#             Predict: 6.43150406504065
#            Else (feature 10 > 4.375)
#             Predict: 5.6697666487165685
#           Else (feature 9 > 6.5)
#            If (feature 8 <= 19.5)
#             Predict: 4.826918238993711
#            Else (feature 8 > 19.5)
#             Predict: 5.340872888173773
#      Else (feature 10 > 8.215)
#       If (feature 8 <= 6.5)
#        If (feature 10 <= 8.47)
#         Predict: 628.5469014084506
#        Else (feature 10 > 8.47)
#         If (feature 5 <= 27.85)
#          If (feature 5 <= 24.25)
#           If (feature 8 <= 0.5)
#            Predict: 5.122678571428572
#           Else (feature 8 > 0.5)
#            Predict: 4.871833333333332
#          Else (feature 5 > 24.25)
#           If (feature 1 <= 184.0)
#            If (feature 1 <= 135.0)
#             Predict: 5.6008219178082195
#            Else (feature 1 > 135.0)
#             Predict: 6.082716049382717
#           Else (feature 1 > 184.0)
#            Predict: 5.411249999999997
#         Else (feature 5 > 27.85)
#          If (feature 10 <= 12.22)
#           If (feature 1 <= 160.0)
#            If (feature 1 <= 115.0)
#             Predict: 6.938734177215189
#            Else (feature 1 > 115.0)
#             Predict: 7.294324324324324
#           Else (feature 1 > 160.0)
#            If (feature 9 <= 4.5)
#             Predict: 6.5649056603773595
#            Else (feature 9 > 4.5)
#             Predict: 6.908363636363635
#          Else (feature 10 > 12.22)
#           If (feature 7 <= 57.925)
#            If (feature 0 <= 170.5)
#             Predict: 7.578197674418604
#            Else (feature 0 > 170.5)
#             Predict: 7.155245901639349
#           Else (feature 7 > 57.925)
#            If (feature 8 <= 3.5)
#             Predict: 7.759999999999999
#            Else (feature 8 > 3.5)
#             Predict: 8.153728813559322
#       Else (feature 8 > 6.5)
#        If (feature 5 <= 27.85)
#         If (feature 10 <= 9.125)
#          If (feature 10 <= 8.47)
#           If (feature 5 <= 24.25)
#            If (feature 8 <= 10.5)
#             Predict: 5.014583333333333
#            Else (feature 8 > 10.5)
#             Predict: 4.6832710280373835
#           Else (feature 5 > 24.25)
#            If (feature 1 <= 160.0)
#             Predict: 5.724116504854369
#            Else (feature 1 > 160.0)
#             Predict: 4.523666666666668
#          Else (feature 10 > 8.47)
#           If (feature 5 <= 24.25)
#            If (feature 8 <= 18.5)
#             Predict: 3.417316341829085
#            Else (feature 8 > 18.5)
#             Predict: 3.9446022727272694
#           Else (feature 5 > 24.25)
#            If (feature 8 <= 18.5)
#             Predict: 4.024669584245074
#            Else (feature 8 > 18.5)
#             Predict: 4.542614035087721
#         Else (feature 10 > 9.125)
#          If (feature 5 <= 24.25)
#           If (feature 1 <= 138.5)
#            If (feature 1 <= 135.0)
#             Predict: 4.524329268292684
#            Else (feature 1 > 135.0)
#             Predict: 5.029027777777778
#           Else (feature 1 > 138.5)
#            If (feature 1 <= 238.5)
#             Predict: 4.11735632183908
#            Else (feature 1 > 238.5)
#             Predict: 4.785217391304348
#          Else (feature 5 > 24.25)
#           If (feature 1 <= 138.5)
#            If (feature 1 <= 135.0)
#             Predict: 5.3595433789954345
#            Else (feature 1 > 135.0)
#             Predict: 5.991253456221193
#           Else (feature 1 > 138.5)
#            If (feature 1 <= 230.5)
#             Predict: 4.836926952141058
#            Else (feature 1 > 230.5)
#             Predict: 5.316352459016394
#        Else (feature 5 > 27.85)
#         If (feature 10 <= 9.125)
#          If (feature 10 <= 8.47)
#           If (feature 2 <= 1.5)
#            If (feature 8 <= 16.5)
#             Predict: 6.618649517684887
#            Else (feature 8 > 16.5)
#             Predict: 4.610169491525424
#           Else (feature 2 > 1.5)
#            If (feature 7 <= 37.75)
#             Predict: 6.331643835616439
#            Else (feature 7 > 37.75)
#             Predict: 6.968095890410959
#          Else (feature 10 > 8.47)
#           If (feature 8 <= 17.5)
#            If (feature 0 <= 139.5)
#             Predict: 5.090046948356807
#            Else (feature 0 > 139.5)
#             Predict: 4.692175525339927
#           Else (feature 8 > 17.5)
#            If (feature 8 <= 18.5)
#             Predict: 5.2154411764705895
#            Else (feature 8 > 18.5)
#             Predict: 5.692539682539684
#         Else (feature 10 > 9.125)
#          If (feature 10 <= 17.035000000000004)
#           If (feature 1 <= 138.5)
#            If (feature 1 <= 135.0)
#             Predict: 6.6532129963898905
#            Else (feature 1 > 135.0)
#             Predict: 7.129456521739129
#           Else (feature 1 > 138.5)
#            If (feature 1 <= 261.5)
#             Predict: 6.197916241062308
#            Else (feature 1 > 261.5)
#             Predict: 7.632453987730062
#          Else (feature 10 > 17.035000000000004)
#           If (feature 0 <= 113.5)
#            If (feature 8 <= 19.5)
#             Predict: 7.109767441860466
#            Else (feature 8 > 19.5)
#             Predict: 7.356923076923077
#           Else (feature 0 > 113.5)
#            If (feature 7 <= 57.925)
#             Predict: 7.634374176548089
#            Else (feature 7 > 57.925)
#             Predict: 7.873256735340727
#   Else (feature 5 > 32.8)
#    If (feature 5 <= 50.95)
#     If (feature 8 <= 7.5)
#      If (feature 1 <= 68.5)
#       If (feature 9 <= 5.5)
#        If (feature 5 <= 40.05)
#         If (feature 8 <= 4.5)
#          If (feature 10 <= 1.75)
#           Predict: 3.6541379310344833
#          Else (feature 10 > 1.75)
#           If (feature 0 <= 113.5)
#            If (feature 6 <= 7.415)
#             Predict: 7.7780701754385975
#            Else (feature 6 > 7.415)
#             Predict: 7.424262295081967
#           Else (feature 0 > 113.5)
#            If (feature 7 <= 44.535)
#             Predict: 7.804126984126984
#            Else (feature 7 > 44.535)
#             Predict: 8.277785714285713
#         Else (feature 8 > 4.5)
#          If (feature 10 <= 1.75)
#           If (feature 7 <= 37.75)
#            Predict: 8.1244578313253
#           Else (feature 7 > 37.75)
#            If (feature 1 <= 48.5)
#             Predict: 10.226
#            Else (feature 1 > 48.5)
#             Predict: 9.26098039215686
#          Else (feature 10 > 1.75)
#           If (feature 10 <= 4.125)
#            Predict: 7.017352941176471
#           Else (feature 10 > 4.125)
#            Predict: 8.059791666666667
#        Else (feature 5 > 40.05)
#         If (feature 0 <= 68.5)
#          If (feature 10 <= 4.125)
#           Predict: 6.903194444444444
#          Else (feature 10 > 4.125)
#           Predict: 10.929857142857141
#         Else (feature 0 > 68.5)
#          If (feature 2 <= 1.5)
#           If (feature 0 <= 151.5)
#            If (feature 10 <= 1.75)
#             Predict: 11.454999999999995
#            Else (feature 10 > 1.75)
#             Predict: 10.448148148148148
#           Else (feature 0 > 151.5)
#            If (feature 10 <= 3.875)
#             Predict: 11.291044776119403
#            Else (feature 10 > 3.875)
#             Predict: 12.437254901960783
#          Else (feature 2 > 1.5)
#           If (feature 0 <= 170.5)
#            If (feature 9 <= 2.5)
#             Predict: 10.970757575757574
#            Else (feature 9 > 2.5)
#             Predict: 10.4328
#           Else (feature 0 > 170.5)
#            Predict: 9.467999999999998
#       Else (feature 9 > 5.5)
#        If (feature 7 <= 44.535)
#         If (feature 8 <= 4.5)
#          Predict: 7.2251315789473685
#         Else (feature 8 > 4.5)
#          Predict: 1648.6345945945948
#        Else (feature 7 > 44.535)
#         If (feature 5 <= 40.05)
#          If (feature 10 <= 6.875)
#           Predict: 7.594935064935066
#          Else (feature 10 > 6.875)
#           Predict: 8.554999999999998
#         Else (feature 5 > 40.05)
#          If (feature 8 <= 5.5)
#           If (feature 9 <= 6.5)
#            Predict: 10.241428571428571
#           Else (feature 9 > 6.5)
#            If (feature 8 <= 1.5)
#             Predict: 10.019814814814813
#            Else (feature 8 > 1.5)
#             Predict: 8.65456140350877
#          Else (feature 8 > 5.5)
#           Predict: 11.490229885057472
#      Else (feature 1 > 68.5)
#       If (feature 0 <= 229.5)
#        If (feature 5 <= 40.05)
#         If (feature 10 <= 9.125)
#          If (feature 8 <= 4.5)
#           If (feature 10 <= 4.125)
#            If (feature 6 <= 0.005)
#             Predict: 6.60560975609756
#            Else (feature 6 > 0.005)
#             Predict: 2.528333333333337
#           Else (feature 10 > 4.125)
#            If (feature 10 <= 4.375)
#             Predict: 8.730542168674697
#            Else (feature 10 > 4.375)
#             Predict: 7.715096018735364
#          Else (feature 8 > 4.5)
#           If (feature 1 <= 229.5)
#            If (feature 6 <= 0.005)
#             Predict: 8.816761658031094
#            Else (feature 6 > 0.005)
#             Predict: 8.00895833333333
#           Else (feature 1 > 229.5)
#            If (feature 1 <= 235.5)
#             Predict: 6.630526315789474
#            Else (feature 1 > 235.5)
#             Predict: 7.628457446808511
#         Else (feature 10 > 9.125)
#          If (feature 7 <= 57.925)
#           If (feature 6 <= 7.415)
#            If (feature 0 <= 132.5)
#             Predict: 8.531219512195122
#            Else (feature 0 > 132.5)
#             Predict: 8.857648578811371
#           Else (feature 6 > 7.415)
#            If (feature 10 <= 10.095)
#             Predict: 8.778076923076922
#            Else (feature 10 > 10.095)
#             Predict: 8.25254716981132
#          Else (feature 7 > 57.925)
#           If (feature 1 <= 240.0)
#            If (feature 0 <= 143.5)
#             Predict: 9.243806122448978
#            Else (feature 0 > 143.5)
#             Predict: 8.84169590643274
#           Else (feature 1 > 240.0)
#            If (feature 6 <= 10.01)
#             Predict: 8.50865671641791
#            Else (feature 6 > 10.01)
#             Predict: 8.657804878048779
#        Else (feature 5 > 40.05)
#         If (feature 10 <= 7.965)
#          If (feature 8 <= 4.5)
#           If (feature 10 <= 3.875)
#            If (feature 2 <= 1.5)
#             Predict: 9.347619047619048
#            Else (feature 2 > 1.5)
#             Predict: 4.4078899082568785
#           Else (feature 10 > 3.875)
#            If (feature 10 <= 4.75)
#             Predict: 10.989847328244274
#            Else (feature 10 > 4.75)
#             Predict: 10.027589285714287
#          Else (feature 8 > 4.5)
#           If (feature 2 <= 1.5)
#            If (feature 8 <= 5.5)
#             Predict: 10.077639751552793
#            Else (feature 8 > 5.5)
#             Predict: 11.507449209932282
#           Else (feature 2 > 1.5)
#            If (feature 1 <= 135.0)
#             Predict: 10.734802631578953
#            Else (feature 1 > 135.0)
#             Predict: 9.281007751937999
#         Else (feature 10 > 7.965)
#          If (feature 1 <= 233.5)
#           If (feature 7 <= 73.545)
#            If (feature 6 <= 7.415)
#             Predict: 11.171661538461537
#            Else (feature 6 > 7.415)
#             Predict: 10.63420516836336
#           Else (feature 7 > 73.545)
#            If (feature 0 <= 139.5)
#             Predict: 11.505842696629221
#            Else (feature 0 > 139.5)
#             Predict: 10.667898550724624
#          Else (feature 1 > 233.5)
#           If (feature 7 <= 57.925)
#            Predict: 8.81294117647059
#           Else (feature 7 > 57.925)
#            If (feature 1 <= 240.0)
#             Predict: 10.191785714285714
#            Else (feature 1 > 240.0)
#             Predict: 11.332000000000006
#       Else (feature 0 > 229.5)
#        If (feature 0 <= 231.5)
#         If (feature 10 <= 12.22)
#          If (feature 5 <= 40.05)
#           If (feature 1 <= 233.5)
#            Predict: 7.357283950617284
#           Else (feature 1 > 233.5)
#            Predict: 8.075084745762709
#          Else (feature 5 > 40.05)
#           Predict: 9.082054794520548
#         Else (feature 10 > 12.22)
#          Predict: 671.6023958333334
#        Else (feature 0 > 231.5)
#         If (feature 2 <= 1.5)
#          If (feature 0 <= 262.5)
#           If (feature 5 <= 40.05)
#            If (feature 1 <= 138.5)
#             Predict: 8.21981981981982
#            Else (feature 1 > 138.5)
#             Predict: 7.407058823529411
#           Else (feature 5 > 40.05)
#            If (feature 0 <= 237.5)
#             Predict: 9.173333333333336
#            Else (feature 0 > 237.5)
#             Predict: 10.913907284768213
#          Else (feature 0 > 262.5)
#           If (feature 6 <= 5.390000000000001)
#            Predict: 198.03799999999998
#           Else (feature 6 > 5.390000000000001)
#            Predict: 8.632812500000028
#         Else (feature 2 > 1.5)
#          If (feature 10 <= 1.75)
#           If (feature 9 <= 4.5)
#            Predict: 2.2525490196078426
#           Else (feature 9 > 4.5)
#            Predict: 1.2205769230769232
#          Else (feature 10 > 1.75)
#           If (feature 5 <= 40.05)
#            If (feature 1 <= 138.5)
#             Predict: 8.522175824175822
#            Else (feature 1 > 138.5)
#             Predict: 7.353380855397146
#           Else (feature 5 > 40.05)
#            If (feature 0 <= 262.5)
#             Predict: 10.255686274509804
#            Else (feature 0 > 262.5)
#             Predict: 8.174117647058825
#     Else (feature 8 > 7.5)
#      If (feature 5 <= 40.05)
#       If (feature 0 <= 262.5)
#        If (feature 10 <= 9.125)
#         If (feature 10 <= 3.875)
#          If (feature 6 <= 0.015)
#           If (feature 7 <= 37.75)
#            If (feature 8 <= 19.5)
# ...
#         If (feature 2 <= 1.5)
#          If (feature 5 <= 69.95)
#           If (feature 8 <= 12.5)
#            If (feature 8 <= 6.5)
#             Predict: 13.649999999999999
#            Else (feature 8 > 6.5)
#             Predict: 15.007079646017699
#           Else (feature 8 > 12.5)
#            If (feature 0 <= 53.5)
#             Predict: 12.175714285714285
#            Else (feature 0 > 53.5)
#             Predict: 13.945614035087717
#          Else (feature 5 > 69.95)
#           Predict: 21.844067796610172
#         Else (feature 2 > 1.5)
#          If (feature 0 <= 33.5)
#           If (feature 7 <= 73.545)
#            If (feature 6 <= 1.005)
#             Predict: 12.182830188679246
#            Else (feature 6 > 1.005)
#             Predict: 10.392641509433966
#           Else (feature 7 > 73.545)
#            If (feature 1 <= 230.5)
#             Predict: 15.489666666666668
#            Else (feature 1 > 230.5)
#             Predict: 11.887222222222224
#          Else (feature 0 > 33.5)
#           If (feature 5 <= 69.95)
#            If (feature 9 <= 2.5)
#             Predict: 11.571666666666667
#            Else (feature 9 > 2.5)
#             Predict: 9.989510869565214
#           Else (feature 5 > 69.95)
#            If (feature 8 <= 17.5)
#             Predict: 8.828620689655171
#            Else (feature 8 > 17.5)
#             Predict: 3.9014000000000033
#        Else (feature 0 > 113.5)
#         If (feature 10 <= 3.875)
#          If (feature 6 <= 0.005)
#           If (feature 4 <= 1.5)
#            Predict: 12.687727272727274
#           Else (feature 4 > 1.5)
#            Predict: 15.136285714285718
#          Else (feature 6 > 0.005)
#           If (feature 1 <= 192.0)
#            Predict: 13.615
#           Else (feature 1 > 192.0)
#            If (feature 8 <= 14.5)
#             Predict: 10.121615384615383
#            Else (feature 8 > 14.5)
#             Predict: 6.534545454545451
#         Else (feature 10 > 3.875)
#          If (feature 5 <= 69.95)
#           Predict: 13.306216216216216
#          Else (feature 5 > 69.95)
#           If (feature 1 <= 230.5)
#            If (feature 8 <= 15.5)
#             Predict: 17.095746606334842
#            Else (feature 8 > 15.5)
#             Predict: 17.73412587412591
#           Else (feature 1 > 230.5)
#            If (feature 8 <= 14.5)
#             Predict: 18.583719999999996
#            Else (feature 8 > 14.5)
#             Predict: 17.06845070422535
#       Else (feature 0 > 132.5)
#        If (feature 5 <= 69.95)
#         If (feature 2 <= 1.5)
#          If (feature 0 <= 245.5)
#           If (feature 9 <= 3.5)
#            Predict: 11.195959595959597
#           Else (feature 9 > 3.5)
#            If (feature 9 <= 5.5)
#             Predict: 14.645535714285714
#            Else (feature 9 > 5.5)
#             Predict: 10.966101694915258
#          Else (feature 0 > 245.5)
#           Predict: 7.201851851851862
#         Else (feature 2 > 1.5)
#          If (feature 10 <= 3.875)
#           If (feature 4 <= 1.5)
#            If (feature 6 <= 4.01)
#             Predict: 1.105087719298246
#            Else (feature 6 > 4.01)
#             Predict: 2.782
#           Else (feature 4 > 1.5)
#            Predict: 4.971960784313724
#          Else (feature 10 > 3.875)
#           If (feature 0 <= 167.0)
#            Predict: 8.630609756097561
#           Else (feature 0 > 167.0)
#            If (feature 9 <= 6.5)
#             Predict: 10.222279202279202
#            Else (feature 9 > 6.5)
#             Predict: 12.14540000000001
#        Else (feature 5 > 69.95)
#         If (feature 0 <= 262.5)
#          If (feature 1 <= 261.5)
#           If (feature 8 <= 15.5)
#            If (feature 4 <= 2.5)
#             Predict: 1.8593769470404966
#            Else (feature 4 > 2.5)
#             Predict: 0.41788461538461574
#           Else (feature 8 > 15.5)
#            If (feature 1 <= 192.0)
#             Predict: 0.3789594594594595
#            Else (feature 1 > 192.0)
#             Predict: 0.9258059701492535
#          Else (feature 1 > 261.5)
#           Predict: 6.177678571428568
#         Else (feature 0 > 262.5)
#          If (feature 1 <= 261.5)
#           If (feature 10 <= 1.75)
#            If (feature 6 <= 1.505)
#             Predict: 14.75158536585366
#            Else (feature 6 > 1.505)
#             Predict: 5.93311557788945
#           Else (feature 10 > 1.75)
#            Predict: 21.56861111111111
#          Else (feature 1 > 261.5)
#           If (feature 10 <= 1.75)
#            If (feature 4 <= 1.5)
#             Predict: 1.0711482254697284
#            Else (feature 4 > 1.5)
#             Predict: 5.795238095238094
#           Else (feature 10 > 1.75)
#            Predict: 8.049855072463767
#     Else (feature 10 > 4.125)
#      If (feature 1 <= 79.5)
#       If (feature 7 <= 73.545)
#        If (feature 9 <= 5.5)
#         If (feature 2 <= 1.5)
#          If (feature 6 <= 0.025)
#           If (feature 9 <= 4.5)
#            If (feature 8 <= 8.5)
#             Predict: 12.014102564102567
#            Else (feature 8 > 8.5)
#             Predict: 13.825257731958764
#           Else (feature 9 > 4.5)
#            Predict: 15.234020618556698
#          Else (feature 6 > 0.025)
#           Predict: 11.680281690140848
#         Else (feature 2 > 1.5)
#          If (feature 8 <= 20.5)
#           If (feature 8 <= 13.5)
#            If (feature 10 <= 10.095)
#             Predict: 12.808666666666666
#            Else (feature 10 > 10.095)
#             Predict: 11.780133333333334
#           Else (feature 8 > 13.5)
#            If (feature 10 <= 6.625)
#             Predict: 10.29855072463768
#            Else (feature 10 > 6.625)
#             Predict: 11.767572815533983
#          Else (feature 8 > 20.5)
#           Predict: 13.158771929824548
#        Else (feature 9 > 5.5)
#         If (feature 1 <= 68.5)
#          If (feature 8 <= 16.5)
#           If (feature 0 <= 170.5)
#            Predict: 14.420106382978723
#           Else (feature 0 > 170.5)
#            Predict: 13.057499999999992
#          Else (feature 8 > 16.5)
#           Predict: 11.393835616438356
#         Else (feature 1 > 68.5)
#          If (feature 8 <= 13.5)
#           Predict: 1766.830714285714
#          Else (feature 8 > 13.5)
#           Predict: 12.703857142857201
#       Else (feature 7 > 73.545)
#        If (feature 5 <= 69.95)
#         If (feature 1 <= 44.0)
#          If (feature 7 <= 90.94999999999999)
#           If (feature 6 <= 6.145)
#            Predict: 15.902830188679241
#           Else (feature 6 > 6.145)
#            If (feature 10 <= 9.125)
#             Predict: 12.511263157894737
#            Else (feature 10 > 9.125)
#             Predict: 13.841398601398598
#          Else (feature 7 > 90.94999999999999)
#           If (feature 8 <= 14.5)
#            Predict: 16.148615384615386
#           Else (feature 8 > 14.5)
#            Predict: 15.104230769230766
#         Else (feature 1 > 44.0)
#          If (feature 7 <= 90.94999999999999)
#           If (feature 6 <= 0.015)
#            If (feature 8 <= 15.5)
#             Predict: 14.650181818181817
#            Else (feature 8 > 15.5)
#             Predict: 13.014531250000005
#           Else (feature 6 > 0.015)
#            If (feature 8 <= 18.5)
#             Predict: 11.753754901960784
#            Else (feature 8 > 18.5)
#             Predict: 13.04990476190475
#          Else (feature 7 > 90.94999999999999)
#           If (feature 0 <= 142.5)
#            If (feature 10 <= 17.035000000000004)
#             Predict: 15.523012048192768
#            Else (feature 10 > 17.035000000000004)
#             Predict: 13.808058252427184
#           Else (feature 0 > 142.5)
#            If (feature 3 <= 1.5)
#             Predict: 12.943070866141731
#            Else (feature 3 > 1.5)
#             Predict: 12.089999999999991
#        Else (feature 5 > 69.95)
#         If (feature 0 <= 113.5)
#          If (feature 0 <= 33.5)
#           If (feature 1 <= 44.0)
#            If (feature 10 <= 17.035000000000004)
#             Predict: 12.86040983606557
#            Else (feature 10 > 17.035000000000004)
#             Predict: 15.903488372093019
#           Else (feature 1 > 44.0)
#            If (feature 10 <= 17.035000000000004)
#             Predict: 16.745162790697684
#            Else (feature 10 > 17.035000000000004)
#             Predict: 18.016406779661022
#          Else (feature 0 > 33.5)
#           If (feature 1 <= 44.0)
#            If (feature 0 <= 53.5)
#             Predict: 10.044333333333332
#            Else (feature 0 > 53.5)
#             Predict: 14.73048387096774
#           Else (feature 1 > 44.0)
#            If (feature 0 <= 68.5)
#             Predict: 4.717464788732394
#            Else (feature 0 > 68.5)
#             Predict: 9.500689655172415
#         Else (feature 0 > 113.5)
#          If (feature 0 <= 262.5)
#           If (feature 0 <= 140.5)
#            If (feature 1 <= 44.0)
#             Predict: 20.967769423558906
#            Else (feature 1 > 44.0)
#             Predict: 17.741296150824823
#           Else (feature 0 > 140.5)
#            If (feature 10 <= 17.035000000000004)
#             Predict: 13.619953596287704
#            Else (feature 10 > 17.035000000000004)
#             Predict: 17.15952380952381
#          Else (feature 0 > 262.5)
#           If (feature 3 <= 1.5)
#            If (feature 9 <= 3.5)
#             Predict: 26.507222222222218
#            Else (feature 9 > 3.5)
#             Predict: 22.752162162162165
#           Else (feature 3 > 1.5)
#            Predict: 20.603265306122456
#      Else (feature 1 > 79.5)
#       If (feature 5 <= 69.95)
#        If (feature 1 <= 135.0)
#         If (feature 1 <= 131.5)
#          If (feature 2 <= 1.5)
#           If (feature 8 <= 14.5)
#            If (feature 6 <= 2.01)
#             Predict: 15.39010989010989
#            Else (feature 6 > 2.01)
#             Predict: 12.970886075949371
#           Else (feature 8 > 14.5)
#            If (feature 0 <= 161.5)
#             Predict: 11.445454545454545
#            Else (feature 0 > 161.5)
#             Predict: 13.661111111111117
#          Else (feature 2 > 1.5)
#           If (feature 0 <= 250.5)
#            If (feature 10 <= 7.965)
#             Predict: 11.303944954128438
#            Else (feature 10 > 7.965)
#             Predict: 12.536969696969695
#           Else (feature 0 > 250.5)
#            Predict: 8.86119999999999
#         Else (feature 1 > 131.5)
#          If (feature 7 <= 73.545)
#           If (feature 6 <= 7.415)
#            If (feature 7 <= 57.925)
#             Predict: 12.683923076923074
#            Else (feature 7 > 57.925)
#             Predict: 14.534215644820295
#           Else (feature 6 > 7.415)
#            If (feature 10 <= 4.375)
#             Predict: 13.496129032258061
#            Else (feature 10 > 4.375)
#             Predict: 12.840930232558136
#          Else (feature 7 > 73.545)
#           If (feature 6 <= 5.390000000000001)
#            If (feature 10 <= 10.095)
#             Predict: 16.361176470588237
#            Else (feature 10 > 10.095)
#             Predict: 17.14510917030567
#           Else (feature 6 > 5.390000000000001)
#            If (feature 8 <= 19.5)
#             Predict: 14.96189949748744
#            Else (feature 8 > 19.5)
#             Predict: 15.890810234541574
#        Else (feature 1 > 135.0)
#         If (feature 0 <= 89.5)
#          If (feature 7 <= 90.94999999999999)
#           If (feature 6 <= 4.625)
#            If (feature 7 <= 73.545)
#             Predict: 13.092736455463735
#            Else (feature 7 > 73.545)
#             Predict: 14.724961038961036
#           Else (feature 6 > 4.625)
#            If (feature 7 <= 73.545)
#             Predict: 11.642329192546581
#            Else (feature 7 > 73.545)
#             Predict: 12.930572115384598
#          Else (feature 7 > 90.94999999999999)
#           If (feature 0 <= 33.5)
#            If (feature 1 <= 160.0)
#             Predict: 15.495900900900894
#            Else (feature 1 > 160.0)
#             Predict: 14.527121212121225
#           Else (feature 0 > 33.5)
#            If (feature 0 <= 78.5)
#             Predict: 13.217663934426232
#            Else (feature 0 > 78.5)
#             Predict: 14.758578947368417
#         Else (feature 0 > 89.5)
#          If (feature 10 <= 7.965)
#           If (feature 1 <= 138.5)
#            If (feature 6 <= 5.390000000000001)
#             Predict: 3.733508771929825
#            Else (feature 6 > 5.390000000000001)
#             Predict: 1.1127049180327866
#           Else (feature 1 > 138.5)
#            If (feature 10 <= 5.125)
#             Predict: 12.92894117647058
#            Else (feature 10 > 5.125)
#             Predict: 10.718955007256893
#          Else (feature 10 > 7.965)
#           If (feature 7 <= 90.94999999999999)
#            If (feature 8 <= 18.5)
#             Predict: 11.854251165134148
#            Else (feature 8 > 18.5)
#             Predict: 13.181052254831778
#           Else (feature 7 > 90.94999999999999)
#            If (feature 8 <= 18.5)
#             Predict: 13.122744874715261
#            Else (feature 8 > 18.5)
#             Predict: 14.514047619047622
#       Else (feature 5 > 69.95)
#        If (feature 0 <= 262.5)
#         If (feature 1 <= 135.0)
#          If (feature 1 <= 131.5)
#           If (feature 0 <= 143.5)
#            If (feature 0 <= 113.5)
#             Predict: 13.482805369127517
#            Else (feature 0 > 113.5)
#             Predict: 17.271814921090385
#           Else (feature 0 > 143.5)
#            If (feature 0 <= 170.5)
#             Predict: 9.60909090909091
#            Else (feature 0 > 170.5)
#             Predict: 12.598784530386743
#          Else (feature 1 > 131.5)
#           If (feature 0 <= 33.5)
#            If (feature 10 <= 17.035000000000004)
#             Predict: 20.872582720588234
#            Else (feature 10 > 17.035000000000004)
#             Predict: 29.578046511627903
#           Else (feature 0 > 33.5)
#            If (feature 0 <= 237.5)
#             Predict: 18.421167212422098
#            Else (feature 0 > 237.5)
#             Predict: 20.384432053528748
#         Else (feature 1 > 135.0)
#          If (feature 0 <= 132.5)
#           If (feature 1 <= 235.5)
#            If (feature 10 <= 17.035000000000004)
#             Predict: 17.18094837587007
#            Else (feature 10 > 17.035000000000004)
#             Predict: 18.54266210229562
#           Else (feature 1 > 235.5)
#            If (feature 0 <= 113.5)
#             Predict: 17.763560500695416
#            Else (feature 0 > 113.5)
#             Predict: 19.430797897754406
#          Else (feature 0 > 132.5)
#           If (feature 10 <= 17.035000000000004)
#            If (feature 0 <= 228.5)
#             Predict: 9.27565010211028
#            Else (feature 0 > 228.5)
#             Predict: 5.330751104565535
#           Else (feature 10 > 17.035000000000004)
#            If (feature 8 <= 12.5)
#             Predict: 17.691592920353983
#            Else (feature 8 > 12.5)
#             Predict: 13.327743190661483
#        Else (feature 0 > 262.5)
#         If (feature 7 <= 90.94999999999999)
#          If (feature 1 <= 135.0)
#           If (feature 10 <= 6.625)
#            If (feature 8 <= 20.5)
#             Predict: 14.731341463414635
#            Else (feature 8 > 20.5)
#             Predict: 16.6222
#           Else (feature 10 > 6.625)
#            If (feature 3 <= 1.5)
#             Predict: 18.649385474860335
#            Else (feature 3 > 1.5)
#             Predict: 19.551428571428573
#          Else (feature 1 > 135.0)
#           If (feature 10 <= 12.22)
#            Predict: 16.06282828282828
#           Else (feature 10 > 12.22)
#            Predict: 13.087142857142855
#         Else (feature 7 > 90.94999999999999)
#          If (feature 6 <= 0.015)
#           If (feature 1 <= 135.0)
#            If (feature 10 <= 7.625)
#             Predict: 25.221403508771928
#            Else (feature 10 > 7.625)
#             Predict: 36.41049676025917
#           Else (feature 1 > 135.0)
#            If (feature 8 <= 18.5)
#             Predict: 23.23055882352941
#            Else (feature 8 > 18.5)
#             Predict: 30.31681415929201
#          Else (feature 6 > 0.015)
#           If (feature 1 <= 138.5)
#            If (feature 10 <= 17.035000000000004)
#             Predict: 23.33832291666666
#            Else (feature 10 > 17.035000000000004)
#             Predict: 27.787567999999993
#           Else (feature 1 > 138.5)
#            If (feature 1 <= 261.5)
#             Predict: 20.377956989247313
#            Else (feature 1 > 261.5)
#             Predict: 14.018343558282208
